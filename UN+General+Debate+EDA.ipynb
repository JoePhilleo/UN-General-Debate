# %%
# import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import operator

# %matplotlib inline

# load data -- can be found here: https://www.kaggle.com/unitednations/un-general-debates/data

data = pd.read_csv('data_1.csv')

for i in range(2, 11):
    data = pd.concat([data, pd.read_csv('data_' + str(i) + '.csv')], axis=0).reset_index(drop=True)

# %%
# data shape
print('data shape:', data.shape)

# data head
data.head()
# Out:
# data shape: (7507, 4)
#    session  year country                                               text
# 0       44  1989     MDV  ﻿It is indeed a pleasure for me and the member...
# 1       44  1989     FIN  ﻿\nMay I begin by congratulating you. Sir, on ...
# 2       44  1989     NER  ﻿\nMr. President, it is a particular pleasure ...
# 3       44  1989     URY  ﻿\nDuring the debate at the fortieth session o...
# 4       44  1989     ZWE  ﻿I should like at the outset to express my del...

# %%
# look at first and last years in data
data.sort_values(by='year')[:3]
# Out:
#      session  year country                                               text
# 174       25  1970     CAN  \nThe General Assembly is fortunate indeed to ...
# 171       25  1970     LBR  49.\t It gives me great pleasure, Mr. Presiden...
# 172       25  1970     KEN  \n36.\t Mr. President, on behalf of His Excell...

# %%
data.sort_values(by='year')[-3:]
# Out:
#       session  year country                                               text
# 5476       70  2015     BOL  I am enormously happy to be here, on behalf of...
# 5485       70  2015     CRI  Costa Rica would like to congratulate you, Sir...
# 5548       70  2015     MYS  I would like to congratulate Mr. Mogens Lykket...

# %%
# convert text data to lower case (for easier analysis)
data['text'] = data['text'].str.lower()

# remove all data before 1971 -- looks like it might be incomplete
data = data[data['year'] > 1970]

# %%
data['char_count'] = data['text'].str.len()
data['words'] = data['text'].str.split(' ')
data['sentences'] = data['text'].str.split('.')
data['word_count'] = data['words'].str.len()
data['sentence_count'] = data['sentences'].str.len()
data['word_length'] = data['char_count'] / data['word_count']
data['sentence_length'] = data['word_count'] / data['sentence_count']

print('avg char count:', data['char_count'].mean())
print()
print('avg word count:', data['word_count'].mean())
print('avg word length:', data['word_length'].mean())
print()
print('avg sentence count:', data['sentence_count'].mean())
print('avg sentence len:', data['sentence_length'].mean())
# Out:
# avg char count: 17908.235713325266
#
# avg word count: 2730.9312894984537
# avg word length: 6.630625639900695
#
# avg sentence count: 119.26744655102864
# avg sentence len: 23.51915369650372

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(7.5, 8))
all_data = [data]

# plot violin plot
axes[0, 0].violinplot(data['word_count'], showmeans=True, showmedians=False)
axes[0, 0].set_title('Word Count per Speech')

axes[0, 1].violinplot(data['word_length'], showmeans=True, showmedians=False)
axes[0, 1].set_title('Avg. Word Length per Speech')

axes[1, 0].violinplot(data['sentence_count'], showmeans=True, showmedians=False)
axes[1, 0].set_title('Sentence Count per Speech')

axes[1, 1].violinplot(data['sentence_length'], showmeans=True, showmedians=False)
axes[1, 1].set_title('Avg. Sentence Length per Speech')

# add x-tick labels
plt.setp(axes, xticks=[y+1 for y in range(len(all_data))], xticklabels=['Frequency'])

fig.subplots_adjust(wspace=.35, hspace=.32)
plt.show()

# %%
# show top and bottom 5 countries by avg sentence count, avg word count,
# and avg sentence length

a = data['sentence_count'].groupby(data['country']).mean()
print('sentence_count')
print(a.sort_values(ascending=False)[:5])
print()
print(a.sort_values(ascending=False)[-5:])
print()

a = data['word_count'].groupby(data['country']).mean()
print('word_count')
print(a.sort_values(ascending=False)[:5])
print()
print(a.sort_values(ascending=False)[-5:])
print()
print()

a = data['sentence_length'].groupby(data['country']).mean()
print('sentence_length')
print(a.sort_values(ascending=False)[:5])
print()
print(a.sort_values(ascending=False)[-5:])
print()
print()
# Out:
# sentence_count
# country
# DEU    210.790698
# RUS    210.733333
# USA    200.800000
# IRL    193.777778
# FRA    171.488889
# Name: sentence_count, dtype: float64
#
# country
# BRN    60.516129
# UZB    59.500000
# SMR    59.291667
# MNE    56.100000
# TON    54.933333
# Name: sentence_count, dtype: float64
#
# word_count
# country
# RUS    4240.577778
# IRL    4109.244444
# CUB    3951.511111
# LBY    3938.186047
# EGY    3792.477273
# Name: word_count, dtype: float64
#
# country
# PLW    1434.222222
# TON    1421.266667
# LTU    1420.560000
# UZB    1375.100000
# BRN    1086.322581
# Name: word_count, dtype: float64
#
#
# sentence_length
# country
# VAT    29.992076
# BHR    29.592585
# TUN    29.066391
# MAR    28.818642
# PSE    28.581918
# Name: sentence_length, dtype: float64
#
# country
# CHE    18.083795
# NOR    17.552376
# DEU    17.219644
# FIN    17.071593
# SWE    16.691306
# Name: sentence_length, dtype: float64

# %%
topics = [' nuclear', ' weapons', ' nuclear weapons', ' chemical weapons', 
          ' biological weapons', ' mass destruction', ' peace', ' war',
          ' nuclear war', ' civil war', ' terror', ' genocide', ' holocaust',
          ' water', ' famine', ' disease', ' hiv', ' aids', ' malaria', ' cancer',
          ' poverty', ' human rights', ' abortion', ' refugee', ' immigration',
          ' equality', ' democracy', ' freedom', ' sovereignty', ' dictator',
          ' totalitarian', ' vote', ' energy', ' oil',  ' coal',  ' income',
          ' economy', ' growth', ' inflation', ' interest rate', ' security',
          ' cyber', ' trade', ' inequality', ' pollution', ' global warming',
          ' hunger', ' education', ' health', ' sanitation', ' infrastructure',
          ' virus', ' regulation', ' food', ' nutrition', ' transportation',
          ' violence', ' agriculture', ' diplomatic', ' drugs', ' obesity',
          ' islam', ' housing', ' sustainable', 'nuclear energy']

dictionary = {}

for i in topics:    
    dictionary[i] = data['year'][data['text'].str.contains(i)].count() / len(data) * 100

sorted_dictionary = sorted(dictionary.items(), key=operator.itemgetter(1), reverse=True)

labels = [i[0] for i in sorted_dictionary]
values = [i[1] for i in sorted_dictionary]
xs = np.arange(len(labels))

width = .9
plt.figure(figsize=(18, 9))
plt.tick_params(axis='both', which='major', labelsize=12)
plt.tick_params(axis='both', which='minor', labelsize=12)
plt.xticks(rotation=80)
plt.xlabel('Topics')
plt.ylabel('% of Debates Mentioned')
plt.title('Bar Plot of Topics Mentioned')

plt.bar(xs, values, width, align='center')
plt.xticks(xs, labels)
plt.show()

# %%
# Percentage of time mentioned in a debate
sorted_dictionary
# Out:
# [(' peace', 98.386446147640186),
#  (' security', 96.450181524808386),
#  (' war', 85.814172381336562),
#  (' human rights', 63.10340190937206),
#  (' weapons', 59.56702971628345),
#  (' trade', 59.230872663708489),
#  (' freedom', 57.442517144009685),
#  (' poverty', 56.070996369503831),
#  (' nuclear', 55.761731881134871),
#  (' terror', 53.072475460535159),
#  (' economy', 48.810004033884631),
#  (' growth', 46.739276590022861),
#  (' sovereignty', 45.085383891354041),
#  (' democracy', 44.681995428264088),
#  (' violence', 41.764152211913405),
#  (' sustainable', 34.839316928869167),
#  (' equality', 34.82587064676617),
#  (' health', 33.54847384698131),
#  (' nuclear weapons', 31.840796019900498),
#  (' energy', 31.531531531531531),
#  (' food', 28.506118058356865),
#  (' refugee', 28.143068441575902),
#  (' education', 27.685894850073957),
#  (' diplomatic', 26.892564205997044),
#  (' water', 22.038456366814575),
#  (' disease', 21.796423288960604),
#  (' hunger', 21.070324055398682),
#  (' mass destruction', 19.698803280892832),
#  (' islam', 16.3775716014522),
#  (' infrastructure', 15.759042624714267),
#  (' income', 13.970687105015465),
#  (' oil', 13.473174667204518),
#  (' chemical weapons', 13.19080274304155),
#  (' drugs', 12.478149791582627),
#  (' vote', 12.088207610595671),
#  (' inflation', 11.079736452870781),
#  (' agriculture', 10.636009143471831),
#  (' genocide', 9.6678768320559367),
#  (' coal', 8.4308188785800731),
#  (' inequality', 8.2829097754470897),
#  (' hiv', 8.0543229796961135),
#  (' famine', 7.8795213123571335),
#  (' nuclear war', 7.839182466048138),
#  (' civil war', 7.7853973376361436),
#  (' dictator', 6.7096947693962612),
#  (' pollution', 6.6424633588812689),
#  (' regulation', 6.0373806642463359),
#  (' interest rate', 5.3112814306844154),
#  (' holocaust', 5.1902648917574288),
#  (' aids', 4.9616780960064544),
#  (' housing', 4.827215274976469),
#  (' malaria', 4.3565954013715205),
#  ('nuclear energy', 4.3565954013715205),
#  (' global warming', 4.1549011698265428),
#  (' totalitarian', 3.3346779615436333),
#  (' transportation', 3.2540002689256422),
#  (' biological weapons', 2.3530993680247412),
#  (' nutrition', 2.2051902648917574),
#  (' immigration', 2.1379588543767647),
#  (' sanitation', 1.8152480839048004),
#  (' virus', 1.6404464165658197),
#  (' cancer', 1.4656447492268387),
#  (' cyber', 0.65886782304692748),
#  (' abortion', 0.080677692617991126),
#  (' obesity', 0.053785128411994079)]

# %%
# UN Members
data['country'].unique()
# Out:
# array(['MDV', 'FIN', 'NER', 'URY', 'ZWE', 'PHL', 'SDN', 'RUS', 'CHN',
#        'ESP', 'SUR', 'ARG', 'SLV', 'MYS', 'NPL', 'PRT', 'COL', 'BLR',
#        'MAR', 'LCA', 'EGY', 'MEX', 'BEL', 'BRN', 'RWA', 'CAN', 'ALB',
#        'GRC', 'KNA', 'GUY', 'LBR', 'ATG', 'MOZ', 'JPN', 'YDYE', 'GAB',
#        'BGD', 'SWE', 'TUR', 'TCD', 'SYR', 'CMR', 'JAM', 'LUX', 'ITA',
#        'AGO', 'CRI', 'CSK', 'BFA', 'MNG', 'BHR', 'HTI', 'OMN', 'CIV',
#        'TGO', 'CYP', 'MUS', 'MMR', 'ARE', 'GTM', 'GRD', 'LBY', 'LKA',
#        'TZA', 'SGP', 'NOR', 'LAO', 'ISL', 'AFG', 'CHL', 'DMA', 'UKR',
#        'KEN', 'BLZ', 'FRA', 'MLI', 'VCT', 'VEN', 'MLT', 'GHA', 'GIN',
#        'GBR', 'ISR', 'YUG', 'BRB', 'IRQ', 'HUN', 'AUT', 'POL', 'GNB',
#        'BWA', 'MRT', 'SWZ', 'DNK', 'DOM', 'MDG', 'NIC', 'BDI', 'CUB',
#        'IRN', 'PAK', 'SEN', 'BGR', 'YEM', 'STP', 'NLD', 'VUT', 'BOL',
#        'PNG', 'SLB', 'DEU', 'ROU', 'KHM', 'TUN', 'BRA', 'IND', 'IDN',
#        'AUS', 'COD', 'HND', 'GNQ', 'FJI', 'IRL', 'DZA', 'USA', 'LSO',
#        'GMB', 'PER', 'DDR', 'THA', 'JOR', 'COG', 'NGA', 'ECU', 'SAU',
#        'QAT', 'SYC', 'ETH', 'TTO', 'PRY', 'VNM', 'NZL', 'PAN', 'MWI',
#        'DJI', 'BEN', 'SOM', 'ZMB', 'CPV', 'BHS', 'KWT', 'UGA', 'COM',
#        'KOR', 'BIH', 'TON', 'EU', 'HRV', 'NRU', 'ZAF', 'TUV', 'NAM', 'SMR',
#        'LIE', 'MKD', 'TLS', 'FSM', 'KIR', 'BTN', 'SVK', 'SLE', 'WSM',
#        'MNE', 'GEO', 'LTU', 'AND', 'TJK', 'MHL', 'EST', 'LVA', 'CAF',
#        'TKM', 'MDA', 'SSD', 'LBN', 'KGZ', 'AZE', 'PSE', 'PRK', 'CZE',
#        'ERI', 'ARM', 'UZB', 'PLW', 'VAT', 'MCO', 'CHE', 'KAZ', 'SVN'], dtype=object)

# %%
# count number of debates in which a nation participates
countries = data['year'].groupby(data['country']).count()
countries = pd.DataFrame(countries.reset_index(drop=False))
countries.columns = ['country', 'num speeches']

print('Most Vocal Member Nations')
print('max number of speeches given:', countries['num speeches'].max())
print(countries[countries['num speeches'] == countries['num speeches'].max()].country.unique())
print()

countries = countries.sort_values(by='num speeches')
print('Least Vocal Member Nations')
print('min number of speeches given:', countries['num speeches'].min())
print(countries.country[:10].unique().tolist())
# Out:
# Most Vocal Member Nations
# max number of speeches given: 45
# ['AFG' 'ALB' 'ARG' 'AUS' 'AUT' 'BDI' 'BEL' 'BFA' 'BGR' 'BLR' 'BOL' 'BRA'
#  'CAN' 'CHL' 'CHN' 'COG' 'COL' 'CUB' 'CYP' 'DZA' 'ECU' 'ESP' 'ETH' 'FIN'
#  'FRA' 'GBR' 'GHA' 'GRC' 'GTM' 'HUN' 'IDN' 'IND' 'IRL' 'IRN' 'IRQ' 'ISL'
#  'ISR' 'ITA' 'JAM' 'JOR' 'JPN' 'LAO' 'LKA' 'MAR' 'MEX' 'MNG' 'MRT' 'MUS'
#  'MYS' 'NGA' 'NLD' 'NPL' 'NZL' 'PAK' 'PER' 'PHL' 'POL' 'QAT' 'ROU' 'RUS'
#  'RWA' 'SDN' 'SLV' 'SYR' 'TUN' 'TUR' 'TZA' 'UKR' 'URY' 'USA' 'VEN' 'YEM']
#
# Least Vocal Member Nations
# min number of speeches given: 5
# ['SSD', 'EU', 'MNE', 'KIR', 'TLS', 'VAT', 'CHE', 'TON', 'TUV', 'NRU']

# %%
# Plot distribution of number of speeches per country
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(4, 4))
all_data = [countries['num speeches']]
axes.violinplot(countries['num speeches'], showmeans=True, showmedians=False)
axes.set_title('UN Speeches Given per Country')

plt.setp(axes, xticks=[y+1 for y in range(len(all_data))], xticklabels=['Frequency'])
plt.show()

# %%
# Plot a horizontal bar graph displaying the frequency of a given topic by country
def freqMentioned (df, country_list, topic_list, colors):
    data = df.loc[df['country'].isin(country_list)]

    for i in topic_list:
        data[i] = data['text'].str.contains(i)
        data[i].loc[data[i] == False] = np.nan

    country = country_list[0]
    data_out = pd.DataFrame(data.loc[data['country'] == country].count())
    data_out = (data_out.T)[topic_list]
    
    # sort the columns by summed occurence in countries specified
    countries = country_list.copy()
    countries.remove(country)

    for i in countries:
        a = pd.DataFrame(data.loc[data['country'] == i].count())
        a = (a.T)[topic_list].copy()
        data_out = pd.concat([data_out, a], axis=0)

    dictionary = {}
    
    for i in topic_list:
        dictionary[i] = data_out[i].sum()
        
    sorted_dictionary = sorted(dictionary.items(), key=operator.itemgetter(1), reverse=True)
    data_out = data_out[[i[0] for i in sorted_dictionary]]
    data_out.index = country_list
    data_out.T.plot(kind="barh", width=.6, stacked=True, figsize = (10, len(topic_list)/3), color=colors).legend(bbox_to_anchor=(1, 1))
    
    return data_out

# %%
# Permanent Members of the UN Security Council
sec_council = ['USA', 'RUS', 'GBR', 'FRA', 'CHN']

topics = []
for i in sorted_dictionary:
    if i[1] > 1:
        topics.append(i[0])

colors = ['dodgerblue', 'orange', 'navy', 'lightseagreen', 'r']

freqMentioned(data, sec_council, topics, colors)
# Out:
# /Users/JPhilleo/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/JPhilleo/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/JPhilleo/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       peace   security   war   nuclear   weapons   human rights   terror  \
# USA      45         44    43        39        43             40       37
# RUS      45         45    42        40        41             32       33
# GBR      44         45    43        29        29             29       26
# FRA      45         45    43        32        33             35       29
# CHN      45         45    41        36        28             12       17
#
#       freedom   trade   economy       ...          malaria   pollution  \
# USA        40      32        32       ...                5           6
# RUS        30      15        14       ...                2           0
# GBR        29      33        24       ...                2           1
# FRA        28      25        15       ...                3           2
# CHN        13      33        35       ...                0           1
#
#       housing   global warming   virus   sanitation   cancer   immigration  \
# USA         1                1       1            1        1             1
# RUS         3                0       2            0        0             0
# GBR         3                4       0            1        0             0
# FRA         1                3       1            1        1             0
# CHN         0                0       0            0        1             2
#
#       nutrition   transportation
# USA           1                1
# RUS           1                0
# GBR           1                0
# FRA           0                0
# CHN           0                1
#
# [5 rows x 62 columns]

# %% [markdown]
# There are a lot of interesting insights to unpack from this plot. First, it's interesting to note that the permanent members of the UN Security Council (and almost all members of the UN for that matter) are primarily concerned with: **Peace**, **Security**, **War**, **Nuclear Weapons**, **Terrorism**, and **Human Rights**. The others goals -- e.g. education, food, transportation, sustainability, disease, health, sanitation, etc. -- receive a comparably small amount of attention.
#
# The distribution of UN Security Council discussion is interesting too.
#
# **China**, predictably, has little to say on **human rights**, **freedom**, and **global violence**; however, it is surprisingly outspoken about **equality**, **sovereignty**, **trade**, **growth**, and **sustainability**.
#
# The US, France, and Great Britain are typically unified in their debate topics with some exceptions: **Great Britain** seems reluctant to talk about **sovereignty** and **nuclear energy**. At the risk of over-rationalizing, both of these avoidances make sense. For years nations within Great Britain and, more broadly, the United Kingdom have wanted and been denied independence; Great Britain cannot credibly advocate for sovereignty while it faces domestic turmoil in that same domain. Similarly, the use of nuclear power in Great Britain is somewhat controversial, which may explain why GBR is not vocal about nuclear power despite promoting general sustainability.
#
# https://en.wikipedia.org/wiki/Nuclear_power_in_the_United_Kingdom#Public_opinion_and_protests
#
# The **US**, expectedly, is an outsized peddler of **democracy**, **freedom**, **growth**, and **disease** while being rather quiet on **sustainability**, **equality**, and **sovereignty**.
#
# Finally, **Russia** seems to enjoy talking about everything *except* **trade** (remember, it is often the recipient of international sanctions), **economic growth** (makes sense given its mediocre economic performance since 1970), **refugees**, and **food / famine**.

# %%
# Korea & Neighbors
countries = ['USA', 'RUS', 'KOR', 'PRK', 'JPN', 'CHN']

topics = [' united states', ' north korea', ' south korea', ' south china sea', ' asia', ' peace',
          ' navy', ' arsenal', ' aggression', ' treaty', ' dmz', ' missile',
          ' nuclear material', ' sanction', ' terror', ' border', ' seoul',
          ' growth', ' democracy', 'tokyo', ' intervention', ' human right',
          ' recognition', ' ally', ' partner', ' japan', ' china', ' proliferation',
          ' conflict', ' russia', ' rice', ' grain', ' starvation']

colors = ['dodgerblue', 'orange', 'navy', 'pink', 'lightseagreen', 'r']

freqMentioned(data, countries, topics, colors)
# Out:
# /Users/JPhilleo/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/JPhilleo/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/JPhilleo/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       peace   conflict   asia   united states   human right   treaty   terror  \
# USA      45         41     30              45            40       30       37
# RUS      45         43     30              38            32       40       33
# KOR      25         24     22              11            23       17       18
# PRK      25         11     22              25            20        8        9
# JPN      45         40     36              34            28       32       23
# CHN      45         38     37              24            12       22       17
#
#       partner   growth   democracy  ...   tokyo   seoul   starvation  \
# USA        26       32          32  ...       6       2            4
# RUS        37       10          15  ...       1       1            2
# KOR        15       14          18  ...       1      15            3
# PRK         2        1           8  ...       0       1            0
# JPN        23       24          14  ...      31       6            8
# CHN        11       30          21  ...       0       0            2
#
#       nuclear material   ally   grain   navy   rice   south china sea   dmz
# USA                 10      1       3      1      2                 2     0
# RUS                  1      1       1      1      0                 0     0
# KOR                  3      0       0      0      0                 0     1
# PRK                  0      0       0      0      0                 0     0
# JPN                  0      0       0      0      1                 0     0
# CHN                  0      8       4      1      0                 1     0
#
# [6 rows x 33 columns]

# %% [markdown]
# Again, there's a lot to unpack here. North Korea and South Korea seem reluctant to talk about peace or treaties while Japan is adament, vocal, and presumably concerned.
#
# Though China, Russia, the US, and Japan refer to themselves more than any other country by far, South Korea is the largest "referer" to North Korea, and North Korea is similarly the largest "referer" to South Korea. Blame game much? North Korea is also vocal about human rights (unclear if its mentions are rebuttals for human rights abuses or ironic advocacy of the cause) and sanctions.
#
# Another interesting observation is that China and Russia both refer to aggression more than any other country in the UN Security Council. Whether that's because they feel like the victim of aggression or because they are addressing claims of aggression is unclear; given both country's high discussion on peace, conflict, and intervention, the answer is probably a mix of both.

# %%
# Middle East
countries = ['USA', 'ISR', 'IRQ', 'EGY', 'PSE', 'JOR', 'LBN', 'SYR']

topics = [' iran', ' iraq', ' israel', ' egypt', ' palestine', ' terror', ' jordan',
          ' refugee', ' hamas', ' lebanon', ' saudi', ' oil', ' nuclear material',
          ' sanction', ' settlements', ' gaza', ' opec', ' foreign investment',
          ' desalination', ' syria', ' dictator', ' democracy', ' gender equality',
          ' islam', ' jewish', ' judaism', ' jerusalem', ' religion', ' christianity',
          ' mecca', ' sunni', ' shia', ' solar', ' instability', ' civil war', ' peace',
          ' partner', ' ally', ' arab', ' conflict', ' jew', ' free speech']

colors = ['dodgerblue', 'navy', 'r', 'green', 'black', 'orange', 'purple', 'grey']

freqMentioned(data, countries, topics, colors)
# Out:
# /Users/JPhilleo/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/JPhilleo/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/JPhilleo/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       peace   arab   israel   conflict   terror   iraq   lebanon   palestine  \
# USA      45     25       29         41       37     26        14           8
# ISR      45     43       45         39       42     22        36          17
# IRQ      43     40       25         36       29     45        19          27
# EGY      43     43       41         40       26     29        23          33
# PSE      18     17       18         17       13      7         3          18
# JOR      45     44       44         39       23     29        26          38
# LBN      41     39       41         36       26     11        41          28
# SYR      45     45       45         38       28     24        30          23
#
#       syria   jerusalem      ...        judaism   solar   sunni   shia  \
# USA      12           5      ...              0       2       3      4
# ISR      37          28      ...              3       3       1      0
# IRQ       9          13      ...              0       0       1      1
# EGY      30          27      ...              2       0       0      0
# PSE       7          16      ...              1       0       0      0
# JOR      24          34      ...              1       0       0      0
# LBN      25          10      ...              0       0       0      0
# SYR      44          25      ...              0       0       0      0
#
#       mecca   opec   desalination   foreign investment   gender equality  \
# USA       0      1              0                    0                 0
# ISR       0      0              2                    0                 0
# IRQ       0      1              0                    1                 1
# EGY       2      0              0                    0                 0
# PSE       0      0              0                    0                 0
# JOR       0      0              0                    0                 0
# LBN       1      0              0                    0                 0
# SYR       1      0              0                    1                 0
#
#       free speech
# USA             1
# ISR             0
# IRQ             0
# EGY             0
# PSE             0
# JOR             0
# LBN             0
# SYR             0
#
# [8 rows x 42 columns]

# %% [markdown]
# This might not be the best basket of words or countries, but it's interesting nonetheless. The Middle East is a bit too complicated for me to delve into here, but feel free to look around!

# %%
# BRINC + USA + Canada
countries = ['USA', 'RUS', 'CAN', 'NGA', 'IND', 'BRA', 'CHN']

topics = [' oil', ' water', ' crude', 'coal', ' gas', ' solar', 'wheat',
          ' tin ', ' diamond', ' wood', 'ivory', ' plutonium', ' fossil',
          ' pollution', ' carbon', ' global warming', ' climate change', 
          ' fertilizer', ' aluminum', ' steel', ' iron', ' timber', ' siicon',
          ' gold', ' silver', ' copper', ' lithium', ' salt', ' magnesium',
          ' rubber', ' paper', ' plastic', ' glass', ' nickel', ' grain',
          ' fruit', ' tariff', ' fish ', ' port ', ' leather', ' nut']

colors = ['dodgerblue', 'orange', 'navy', 'pink', 'mediumseagreen', 'silver', 'r']

freqMentioned(data, countries, topics, colors)
# Out:
# /Users/JPhilleo/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/JPhilleo/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/JPhilleo/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       fruit   water   climate change  coal   oil   tariff   iron   wood   gas  \
# USA       6      13                8    20    12        8      9      0     9
# RUS      17      11                6    11     4        3      3      2     1
# CAN       4      12                8     8     6        6      4      2     3
# NGA       3      10                7     0    11        2      4      6     0
# IND       8      10               12     6     6        4      6      6     2
# BRA      23       2               10     3     8       11      3      6     7
# CHN      10       9                8     7     7        3      3      0     0
#
#       paper   ...      diamond   rubber   glass   tin    copper   magnesium  \
# USA       3   ...            0        0       1      0        0           0
# RUS       5   ...            0        0       0      1        0           0
# CAN       4   ...            1        0       0      0        0           0
# NGA       0   ...            1        1       0      0        0           0
# IND       4   ...            0        0       0      0        1           0
# BRA       0   ...            0        0       0      0        0           0
# CHN       5   ...            0        0       0      0        0           0
#
#       nickel   lithium   aluminum   siicon
# USA        0         0          0        0
# RUS        0         0          0        0
# CAN        0         0          0        0
# NGA        0         0          0        0
# IND        0         0          0        0
# BRA        0         0          0        0
# CHN        0         0          0        0
#
# [7 rows x 41 columns]

# %% [markdown]
# So, this is pretty weird. I wasn't expecting fruit to be a high-priority item on the UN's agenda (higher than water and climate change?!), but it is. Thanks Brazil and Russia.
#
# Fruits aside, country topic interest is largely intuitive and sensible. The US cares about cheap energy and is consequently vocal about oil, coal, and gas. Canada and China both do a lot of fishing, and consequently care about international regulations on fish. India has 1.3B people and is projected to be most impacted by higher global temperatures; it thus has opinions on climate change. etc.
#
# To me, the oddest part of this graph is the lack of discussion about lithium, aluminum, magnesium, and other such metals. In the digital era, we might expect the chemical materials underpinning almost all of our electronic devices and batteries to be a strategic asset.

# %%
topics = []
for i in sorted_dictionary:
    if i[1] > 1:
        topics.append(i[0])

def textFreq(df, topic_list):
    data = df.copy()
    for i in topic_list:
        data[i] = data['text'].apply(lambda x: x.count(i))
    return data

def GroupFreq(df, topic_list, grouping_column):
    topic_freq = textFreq(df, topic_list)
    topic_list.append(grouping_column)
    topic_freq = topic_freq[topic_list]
    topic_freq_col = topic_freq.groupby(topic_freq[grouping_column]).sum()
    return topic_freq_col

topic_freq_county = GroupFreq(data, topics, 'country')
plt.matshow(topic_freq_county.corr())
topic_freq_year = GroupFreq(data, topics, 'year')

# %%
topics_keep = []
for i in topic_freq_year.columns:
    if topic_freq_year[i].sum() > 20000:
        topics_keep.append(i)

topic_freq_year[topics_keep].plot()

# %% [markdown]
# Peace has and continues to be the most discussed topic at the UN. This makes sense, but it's interesting to note that occurence of 'peace' has declined from a peak in 1987, though it's been rebounding since.
#
# Also interesting is the decline in discussion of 'nuclear' and 'war'. This might be why 'peace' discussions have declined (less war means fewer calls for 'peace'), or it may indicate the achievement of a stable, long-term geopolitical stand-off on major conflict and nuclear weapons.

# %%
topic_freq_year[[' economy', ' growth', ' trade', ' inflation']].plot()

# %% [markdown]
# Discussion on 'economy' and 'growth' appear to be highly correlated, with talk of growth having plummeted since 2000. During the global recession in 2008-2010 and the ensuing Eurozone crisis, talk of growth and economy did rise, but has again lagged since 2012. Given the sluggish economy, does lack of discussion suggest UN delegates care less about economic growth than in the past or that they feel increasingly unable to affect it?
#
# As an aside, talk of trade has also fallen dramatically since 2000. This trend likely reflects the diminishing returns and opportunities for more trade as well as the strong political realities that remain. Similarly, international concerns about inflation largely died off after the severe cost-push inflation of the late 70s and early 80s.

# %%
topic_freq_year[[' nuclear', ' weapons', ' nuclear weapons']].plot()

# %%
topic_freq_year[[' peace', ' war', ' terror']].plot()

# %% [markdown]
# Since 2001 (i.e. the 9/11 terrorist attack), discussion of "terror" -- including 'terrorism', 'terrorist', etc. has skyrocketed. While the focus on terror cooled from 2005-2013, recent developments e.g. ISIS? appear to have returned attention to the subject.
#
# As noted before, the discussion of "peace" has fallen while the discussion of "war" has remained relatively constant. It is not yet clear how much of "war" refers to the "war on drugs" and "war on terror".

# %%
topic_freq_year[[' nuclear war', ' civil war', ' genocide']].plot()

# %%
topic_freq_year[[' water', ' famine', ' disease', ' hiv']].plot()

# %% [markdown]
# The HIV crisis, which appears to have started ~1998 has been  effectively resolved by 2010 insofar as international attention is concerned. Meanwhile, "famine" has stayed constant while debate around "disease" and "water" have risen dramatically i.e. 2x in 8 years.

# %%
topic_freq_year[[' human rights', ' refugee', ' equality', ' democracy']].plot()

# %% [markdown]
# Human rights are always an important discussion, but are spotlighted by well-publicized global atrocities (e.g. genocides, refugee crises, etc). In 2015, it looks like the refugee crisis may have reinvigorated the human rights debate.

# %%
topic_freq_year[[' freedom', ' sovereignty', ' democracy', ' equality']].plot()

# %% [markdown]
# From 1970-1990, "freedom" and "sovereignty" were closely correlated. Then, in 1990 -- at the collapse of the USSR -- "freedom" became more closely associated with "democracy" and has remained so since.

# %%
topic_freq_year[[' global warming', ' energy', ' water', ' oil']].plot()

# %% [markdown]
# Until 1985, "oil" and "energy" were closely linked. Since then, discussion of "energy" has diverged from "oil" -- probably as new forms of fuel (e.g. natural gas, smart coal, solar energy, etc.) have become available and cost effective. If anything, "oil" now appears to most closely track "global warming".

# %%
# Top five advocates per cause
for i in topic_freq_county.columns:
    topic_freq_county = topic_freq_county.sort_values(by=i, ascending=False)
    print(i)
    print(topic_freq_county.index.tolist()[:5])
    print()
# Out:
#  peace
# ['ISR', 'JPN', 'EGY', 'CHN', 'NPL']
#
#  security
# ['LBY', 'IRQ', 'BHR', 'RUS', 'KWT']
#
#  war
# ['RUS', 'CHN', 'USA', 'ALB', 'ISR']
#
#  human rights
# ['NLD', 'AUT', 'IRL', 'CRI', 'DEU']
#
#  weapons
# ['RUS', 'UKR', 'USA', 'IRN', 'SWE']
#
#  trade
# ['JAM', 'URY', 'TTO', 'BRA', 'LCA']
#
#  freedom
# ['USA', 'ALB', 'CRI', 'NLD', 'LBY']
#
#  poverty
# ['BGD', 'PER', 'TZA', 'NPL', 'DOM']
#
#  nuclear
# ['RUS', 'UKR', 'PAK', 'CHN', 'MNG']
#
#  terror
# ['ISR', 'LBY', 'LKA', 'USA', 'SYR']
#
#  economy
# ['CHN', 'SGP', 'JAM', 'BRA', 'JPN']
#
#  growth
# ['JAM', 'USA', 'DEU', 'CHN', 'IND']
#
#  sovereignty
# ['CUB', 'CHN', 'IRQ', 'KHM', 'VNM']
#
#  democracy
# ['SLV', 'CRI', 'NIC', 'CHL', 'USA']
#
#  violence
# ['IRL', 'VEN', 'SWE', 'SLV', 'URY']
#
#  sustainable
# ['BRB', 'TJK', 'TTO', 'FIN', 'FSM']
#
#  equality
# ['CHN', 'LBY', 'ROU', 'YEM', 'YUG']
#
#  health
# ['KNA', 'BDI', 'GMB', 'CAN', 'SLV']
#
#  nuclear weapons
# ['RUS', 'CHN', 'NZL', 'UKR', 'PAK']
#
#  energy
# ['USA', 'DEU', 'AUS', 'AUT', 'TKM']
#
#  food
# ['BGD', 'MWI', 'THA', 'GMB', 'KEN']
#
#  refugee
# ['SDN', 'JPN', 'TZA', 'SOM', 'JOR']
#
#  education
# ['CRI', 'BGD', 'AND', 'BDI', 'GTM']
#
#  diplomatic
# ['BRA', 'KHM', 'ISR', 'JPN', 'PRT']
#
#  water
# ['TJK', 'PAN', 'BGD', 'BOL', 'ISR']
#
#  disease
# ['USA', 'GHA', 'CUB', 'KNA', 'LBR']
#
#  hunger
# ['IRL', 'BRA', 'CUB', 'DEU', 'CPV']
#
#  mass destruction
# ['RUS', 'LBY', 'EGY', 'IRN', 'MNG']
#
#  islam
# ['IRN', 'AFG', 'SAU', 'PAK', 'MRT']
#
#  infrastructure
# ['MOZ', 'DMA', 'UGA', 'COD', 'TKM']
#
#  income
# ['DOM', 'BGD', 'COL', 'BOL', 'ATG']
#
#  oil
# ['IRQ', 'IRN', 'VEN', 'CUB', 'DOM']
#
#  chemical weapons
# ['IRN', 'UKR', 'USA', 'DEU', 'RUS']
#
#  drugs
# ['COL', 'MMR', 'BHS', 'BOL', 'THA']
#
#  vote
# ['CUB', 'CHL', 'SGP', 'BGD', 'CRI']
#
#  inflation
# ['CUB', 'BOL', 'HTI', 'VEN', 'BRA']
#
#  agriculture
# ['GMB', 'MWI', 'CAF', 'ISR', 'BGD']
#
#  genocide
# ['RWA', 'ARM', 'CUB', 'BIH', 'BDI']
#
#  coal
# ['KHM', 'USA', 'RUS', 'MNG', 'HUN']
#
#  inequality
# ['DOM', 'CUB', 'PER', 'PAN', 'BRA']
#
#  hiv
# ['MWI', 'KNA', 'SWZ', 'LSO', 'PNG']
#
#  famine
# ['USA', 'IRL', 'BEN', 'SOM', 'DJI']
#
#  nuclear war
# ['RUS', 'UKR', 'BLR', 'DDR', 'CHN']
#
#  civil war
# ['LBR', 'BWA', 'COG', 'SEN', 'TJK']
#
#  dictator
# ['USA', 'NIC', 'TUN', 'CRI', 'IRQ']
#
#  pollution
# ['ISL', 'OMN', 'MCO', 'COD', 'CAN']
#
#  regulation
# ['IRN', 'URY', 'ISL', 'POL', 'CHL']
#
#  interest rate
# ['ROU', 'DOM', 'MEX', 'BRA', 'PER']
#
#  holocaust
# ['ISR', 'CRI', 'CUB', 'PAK', 'ECU']
#
#  aids
# ['USA', 'GAB', 'MWI', 'SWZ', 'CIV']
#
#  housing
# ['JAM', 'LKA', 'GTM', 'CRI', 'MEX']
#
#  malaria
# ['NGA', 'PNG', 'GMB', 'KHM', 'STP']
#
# nuclear energy
# ['IND', 'PAK', 'USA', 'AUS', 'IRN']
#
#  global warming
# ['MDV', 'KHM', 'FSM', 'PLW', 'VCT']
#
#  totalitarian
# ['CHL', 'CRI', 'SLV', 'BGR', 'USA']
#
#  transportation
# ['TKM', 'MNG', 'AZE', 'NPL', 'KAZ']
#
#  biological weapons
# ['USA', 'AUS', 'KOR', 'IRN', 'CHN']
#
#  nutrition
# ['BGD', 'PER', 'COL', 'HND', 'IRL']
#
#  immigration
# ['LBY', 'MLT', 'ITA', 'IRQ', 'BHS']
#
#  sanitation
# ['TJK', 'SGP', 'HUN', 'SLV', 'ATG']
#
#  virus
# ['LBR', 'CUB', 'SLE', 'GIN', 'AND']
#
#  cancer
# ['ATG', 'URY', 'ISR', 'ZMB', 'IRN']

# %%
# Top seven priorities for each UN member country
topic_freq_county = topic_freq_county.sort_index()
topic_freq_county = topic_freq_county.T

for i in topic_freq_county.columns:
    topic_freq_county = topic_freq_county.sort_values(by=i, ascending=False)
    print(i)
    print(topic_freq_county.index.tolist()[:7])
    print()
# Out:
# AFG
# [' peace', ' security', ' war', ' islam', ' terror', ' nuclear', ' weapons']
#
# AGO
# [' peace', ' security', ' war', ' poverty', ' sovereignty', ' terror', ' trade']
#
# ALB
# [' peace', ' security', ' war', ' freedom', ' weapons', ' sovereignty', ' terror']
#
# AND
# [' peace', ' war', ' human rights', ' terror', ' education', ' security', ' democracy']
#
# ARE
# [' peace', ' security', ' war', ' nuclear', ' terror', ' sovereignty', ' weapons']
#
# ARG
# [' peace', ' security', ' terror', ' nuclear', ' war', ' human rights', ' sovereignty']
#
# ARM
# [' peace', ' security', ' genocide', ' war', ' human rights', ' terror', ' economy']
#
# ATG
# [' peace', ' security', ' trade', ' war', ' poverty', ' terror', ' sustainable']
#
# AUS
# [' peace', ' security', ' nuclear', ' human rights', ' weapons', ' war', ' trade']
#
# AUT
# [' peace', ' security', ' human rights', ' nuclear', ' war', ' terror', ' weapons']
#
# AZE
# [' security', ' peace', ' sovereignty', ' refugee', ' war', ' terror', ' economy']
#
# BDI
# [' peace', ' security', ' war', ' freedom', ' refugee', ' poverty', ' weapons']
#
# BEL
# [' peace', ' security', ' human rights', ' war', ' nuclear', ' weapons', ' terror']
#
# BEN
# [' peace', ' security', ' war', ' poverty', ' human rights', ' freedom', ' nuclear']
#
# BFA
# [' peace', ' security', ' war', ' trade', ' food', ' human rights', ' freedom']
#
# BGD
# [' peace', ' security', ' war', ' poverty', ' nuclear', ' food', ' trade']
#
# BGR
# [' peace', ' security', ' nuclear', ' war', ' weapons', ' human rights', ' terror']
#
# BHR
# [' peace', ' security', ' war', ' terror', ' nuclear', ' weapons', ' human rights']
#
# BHS
# [' peace', ' security', ' trade', ' war', ' drugs', ' human rights', ' freedom']
#
# BIH
# [' peace', ' war', ' security', ' terror', ' human rights', ' genocide', ' democracy']
#
# BLR
# [' peace', ' nuclear', ' security', ' war', ' weapons', ' nuclear weapons', ' human rights']
#
# BLZ
# [' peace', ' security', ' war', ' trade', ' poverty', ' human rights', ' sovereignty']
#
# BOL
# [' peace', ' war', ' democracy', ' security', ' poverty', ' trade', ' sovereignty']
#
# BRA
# [' peace', ' security', ' trade', ' nuclear', ' war', ' democracy', ' human rights']
#
# BRB
# [' peace', ' security', ' trade', ' war', ' sustainable', ' human rights', ' economy']
#
# BRN
# [' peace', ' security', ' war', ' terror', ' nuclear', ' weapons', ' health']
#
# BTN
# [' peace', ' security', ' war', ' nuclear', ' weapons', ' poverty', ' sustainable']
#
# BWA
# [' peace', ' security', ' war', ' human rights', ' trade', ' poverty', ' freedom']
#
# CAF
# [' peace', ' security', ' war', ' freedom', ' human rights', ' trade', ' poverty']
#
# CAN
# [' peace', ' security', ' nuclear', ' human rights', ' war', ' weapons', ' terror']
#
# CHE
# [' peace', ' security', ' human rights', ' war', ' terror', ' poverty', ' sustainable']
#
# CHL
# [' peace', ' security', ' human rights', ' democracy', ' trade', ' terror', ' freedom']
#
# CHN
# [' peace', ' nuclear', ' war', ' security', ' weapons', ' nuclear weapons', ' sovereignty']
#
# CIV
# [' peace', ' security', ' war', ' trade', ' human rights', ' poverty', ' growth']
#
# CMR
# [' peace', ' security', ' war', ' human rights', ' freedom', ' poverty', ' nuclear']
#
# COD
# [' peace', ' security', ' war', ' refugee', ' nuclear', ' weapons', ' freedom']
#
# COG
# [' peace', ' security', ' war', ' freedom', ' democracy', ' nuclear', ' weapons']
#
# COL
# [' peace', ' war', ' security', ' terror', ' trade', ' drugs', ' poverty']
#
# COM
# [' peace', ' security', ' islam', ' war', ' freedom', ' poverty', ' terror']
#
# CPV
# [' peace', ' security', ' human rights', ' war', ' poverty', ' freedom', ' food']
#
# CRI
# [' peace', ' human rights', ' war', ' security', ' democracy', ' freedom', ' terror']
#
# CSK
# [' peace', ' security', ' nuclear', ' war', ' weapons', ' nuclear weapons', ' human rights']
#
# CUB
# [' peace', ' war', ' security', ' sovereignty', ' nuclear', ' weapons', ' terror']
#
# CYP
# [' peace', ' security', ' human rights', ' war', ' freedom', ' sovereignty', ' nuclear']
#
# CZE
# [' peace', ' security', ' terror', ' human rights', ' nuclear', ' weapons', ' war']
#
# DDR
# [' peace', ' security', ' war', ' nuclear', ' weapons', ' nuclear weapons', ' human rights']
#
# DEU
# [' peace', ' security', ' human rights', ' war', ' weapons', ' nuclear', ' freedom']
#
# DJI
# [' peace', ' security', ' war', ' poverty', ' refugee', ' sovereignty', ' terror']
#
# DMA
# [' peace', ' security', ' trade', ' sustainable', ' energy', ' terror', ' human rights']
#
# DNK
# [' peace', ' security', ' human rights', ' weapons', ' terror', ' war', ' nuclear']
#
# DOM
# [' peace', ' security', ' war', ' trade', ' poverty', ' human rights', ' growth']
#
# DZA
# [' peace', ' security', ' war', ' terror', ' freedom', ' nuclear', ' sovereignty']
#
# ECU
# [' peace', ' security', ' human rights', ' trade', ' war', ' nuclear', ' poverty']
#
# EGY
# [' peace', ' security', ' war', ' nuclear', ' weapons', ' terror', ' freedom']
#
# ERI
# [' peace', ' security', ' war', ' terror', ' sovereignty', ' poverty', ' human rights']
#
# ESP
# [' peace', ' security', ' human rights', ' terror', ' freedom', ' war', ' weapons']
#
# EST
# [' security', ' peace', ' human rights', ' terror', ' war', ' sustainable', ' freedom']
#
# ETH
# [' peace', ' security', ' war', ' nuclear', ' freedom', ' poverty', ' weapons']
#
# EU
# [' peace', ' war', ' refugee', ' security', ' weapons', ' violence', ' democracy']
#
# FIN
# [' peace', ' security', ' nuclear', ' human rights', ' weapons', ' war', ' sustainable']
#
# FJI
# [' peace', ' nuclear', ' security', ' trade', ' war', ' human rights', ' weapons']
#
# FRA
# [' peace', ' security', ' war', ' nuclear', ' weapons', ' human rights', ' terror']
#
# FSM
# [' sustainable', ' security', ' peace', ' energy', ' war', ' nuclear', ' human rights']
#
# GAB
# [' peace', ' security', ' war', ' trade', ' weapons', ' poverty', ' human rights']
#
# GBR
# [' peace', ' security', ' war', ' nuclear', ' terror', ' trade', ' weapons']
#
# GEO
# [' peace', ' security', ' war', ' freedom', ' democracy', ' terror', ' human rights']
#
# GHA
# [' peace', ' security', ' war', ' trade', ' nuclear', ' poverty', ' weapons']
#
# GIN
# [' peace', ' security', ' war', ' human rights', ' trade', ' poverty', ' freedom']
#
# GMB
# [' peace', ' security', ' human rights', ' war', ' poverty', ' trade', ' food']
#
# GNB
# [' peace', ' security', ' war', ' poverty', ' freedom', ' human rights', ' trade']
#
# GNQ
# [' peace', ' security', ' war', ' freedom', ' human rights', ' democracy', ' terror']
#
# GRC
# [' peace', ' security', ' human rights', ' war', ' nuclear', ' democracy', ' freedom']
#
# GRD
# [' peace', ' security', ' trade', ' war', ' human rights', ' sustainable', ' freedom']
#
# GTM
# [' peace', ' human rights', ' security', ' trade', ' democracy', ' freedom', ' war']
#
# GUY
# [' peace', ' security', ' war', ' trade', ' growth', ' poverty', ' freedom']
#
# HND
# [' peace', ' security', ' war', ' democracy', ' freedom', ' human rights', ' poverty']
#
# HRV
# [' peace', ' security', ' war', ' human rights', ' terror', ' sustainable', ' weapons']
#
# HTI
# [' peace', ' security', ' war', ' democracy', ' freedom', ' poverty', ' human rights']
#
# HUN
# [' peace', ' security', ' war', ' human rights', ' nuclear', ' weapons', ' terror']
#
# IDN
# [' peace', ' security', ' nuclear', ' war', ' trade', ' poverty', ' economy']
#
# IND
# [' peace', ' nuclear', ' security', ' terror', ' war', ' weapons', ' trade']
#
# IRL
# [' peace', ' security', ' human rights', ' nuclear', ' war', ' violence', ' weapons']
#
# IRN
# [' security', ' islam', ' peace', ' war', ' weapons', ' nuclear', ' terror']
#
# IRQ
# [' security', ' peace', ' war', ' terror', ' nuclear', ' weapons', ' sovereignty']
#
# ISL
# [' peace', ' security', ' human rights', ' war', ' nuclear', ' weapons', ' sustainable']
#
# ISR
# [' peace', ' terror', ' war', ' security', ' nuclear', ' weapons', ' freedom']
#
# ITA
# [' peace', ' security', ' war', ' weapons', ' human rights', ' nuclear', ' freedom']
#
# JAM
# [' peace', ' trade', ' security', ' growth', ' war', ' nuclear', ' economy']
#
# JOR
# [' peace', ' security', ' war', ' refugee', ' nuclear', ' terror', ' weapons']
#
# JPN
# [' peace', ' nuclear', ' security', ' weapons', ' war', ' refugee', ' nuclear weapons']
#
# KAZ
# [' nuclear', ' security', ' peace', ' terror', ' weapons', ' energy', ' sustainable']
#
# KEN
# [' peace', ' security', ' war', ' trade', ' nuclear', ' weapons', ' freedom']
#
# KGZ
# [' security', ' peace', ' terror', ' sustainable', ' nuclear', ' war', ' water']
#
# KHM
# [' peace', ' war', ' security', ' sovereignty', ' freedom', ' poverty', ' food']
#
# KIR
# [' security', ' sustainable', ' peace', ' terror', ' war', ' health', ' food']
#
# KNA
# [' peace', ' security', ' sustainable', ' health', ' war', ' democracy', ' human rights']
#
# KOR
# [' peace', ' nuclear', ' security', ' human rights', ' war', ' weapons', ' terror']
#
# KWT
# [' security', ' peace', ' war', ' terror', ' islam', ' nuclear', ' weapons']
#
# LAO
# [' peace', ' security', ' war', ' nuclear', ' sovereignty', ' weapons', ' economy']
#
# LBN
# [' peace', ' security', ' war', ' sovereignty', ' terror', ' freedom', ' refugee']
#
# LBR
# [' peace', ' security', ' war', ' freedom', ' human rights', ' trade', ' terror']
#
# LBY
# [' security', ' peace', ' terror', ' war', ' weapons', ' human rights', ' nuclear']
#
# LCA
# [' peace', ' trade', ' security', ' war', ' growth', ' poverty', ' sustainable']
#
# LIE
# [' security', ' peace', ' human rights', ' war', ' terror', ' violence', ' sustainable']
#
# LKA
# [' peace', ' terror', ' security', ' war', ' nuclear', ' weapons', ' human rights']
#
# LSO
# [' peace', ' security', ' war', ' weapons', ' nuclear', ' human rights', ' poverty']
#
# LTU
# [' security', ' peace', ' human rights', ' nuclear', ' war', ' terror', ' energy']
#
# LUX
# [' peace', ' security', ' human rights', ' war', ' violence', ' weapons', ' trade']
#
# LVA
# [' security', ' peace', ' human rights', ' terror', ' war', ' sustainable', ' freedom']
#
# MAR
# [' peace', ' security', ' war', ' sovereignty', ' islam', ' trade', ' nuclear']
#
# MCO
# [' peace', ' security', ' sustainable', ' war', ' human rights', ' terror', ' health']
#
# MDA
# [' security', ' peace', ' human rights', ' terror', ' sustainable', ' sovereignty', ' democracy']
#
# MDG
# [' peace', ' security', ' war', ' nuclear', ' weapons', ' poverty', ' human rights']
#
# MDV
# [' peace', ' security', ' nuclear', ' war', ' human rights', ' weapons', ' terror']
#
# MEX
# [' peace', ' security', ' nuclear', ' weapons', ' war', ' human rights', ' trade']
#
# MHL
# [' nuclear', ' security', ' peace', ' sustainable', ' war', ' weapons', ' health']
#
# MKD
# [' peace', ' security', ' human rights', ' terror', ' war', ' democracy', ' poverty']
#
# MLI
# [' peace', ' security', ' war', ' weapons', ' freedom', ' nuclear', ' poverty']
#
# MLT
# [' peace', ' security', ' war', ' freedom', ' nuclear', ' weapons', ' terror']
#
# MMR
# [' peace', ' security', ' nuclear', ' war', ' weapons', ' human rights', ' drugs']
#
# MNE
# [' peace', ' security', ' sustainable', ' human rights', ' freedom', ' terror', ' violence']
#
# MNG
# [' peace', ' security', ' nuclear', ' weapons', ' war', ' nuclear weapons', ' democracy']
#
# MOZ
# [' peace', ' security', ' war', ' freedom', ' terror', ' poverty', ' economy']
#
# MRT
# [' peace', ' security', ' islam', ' war', ' freedom', ' terror', ' democracy']
#
# MUS
# [' peace', ' security', ' war', ' nuclear', ' trade', ' weapons', ' human rights']
#
# MWI
# [' peace', ' security', ' food', ' war', ' poverty', ' human rights', ' hiv']
#
# MYS
# [' peace', ' security', ' war', ' trade', ' nuclear', ' islam', ' freedom']
#
# NAM
# [' peace', ' security', ' war', ' poverty', ' trade', ' nuclear', ' sustainable']
#
# NER
# [' peace', ' security', ' war', ' poverty', ' weapons', ' trade', ' terror']
#
# NGA
# [' peace', ' security', ' nuclear', ' war', ' weapons', ' trade', ' freedom']
#
# NIC
# [' peace', ' war', ' security', ' democracy', ' freedom', ' terror', ' trade']
#
# NLD
# [' peace', ' human rights', ' security', ' nuclear', ' war', ' freedom', ' weapons']
#
# NOR
# [' peace', ' security', ' human rights', ' nuclear', ' war', ' weapons', ' terror']
#
# NPL
# [' peace', ' security', ' nuclear', ' human rights', ' weapons', ' war', ' trade']
#
# NRU
# [' security', ' sustainable', ' peace', ' food', ' energy', ' health', ' nuclear']
#
# NZL
# [' nuclear', ' peace', ' security', ' weapons', ' trade', ' war', ' nuclear weapons']
#
# OMN
# [' peace', ' security', ' war', ' nuclear', ' weapons', ' trade', ' terror']
#
# PAK
# [' peace', ' nuclear', ' security', ' war', ' terror', ' islam', ' weapons']
#
# PAN
# [' peace', ' security', ' war', ' human rights', ' sovereignty', ' trade', ' poverty']
#
# PER
# [' peace', ' security', ' terror', ' democracy', ' poverty', ' trade', ' human rights']
#
# PHL
# [' peace', ' security', ' war', ' nuclear', ' trade', ' human rights', ' weapons']
#
# PLW
# [' security', ' sustainable', ' peace', ' health', ' terror', ' war', ' water']
#
# PNG
# [' peace', ' security', ' nuclear', ' trade', ' sustainable', ' weapons', ' war']
#
# POL
# [' peace', ' security', ' war', ' nuclear', ' human rights', ' weapons', ' freedom']
#
# PRK
# [' peace', ' nuclear', ' security', ' war', ' sovereignty', ' weapons', ' human rights']
#
# PRT
# [' peace', ' security', ' human rights', ' war', ' terror', ' freedom', ' democracy']
#
# PRY
# [' peace', ' security', ' terror', ' war', ' democracy', ' trade', ' freedom']
#
# PSE
# [' peace', ' security', ' freedom', ' refugee', ' war', ' terror', ' sovereignty']
#
# QAT
# [' peace', ' security', ' war', ' nuclear', ' terror', ' weapons', ' freedom']
#
# ROU
# [' peace', ' security', ' nuclear', ' weapons', ' war', ' human rights', ' freedom']
#
# RUS
# [' peace', ' nuclear', ' security', ' weapons', ' war', ' nuclear weapons', ' terror']
#
# RWA
# [' peace', ' security', ' war', ' genocide', ' freedom', ' refugee', ' trade']
#
# SAU
# [' peace', ' security', ' islam', ' terror', ' war', ' weapons', ' nuclear']
#
# SDN
# [' peace', ' security', ' war', ' refugee', ' human rights', ' terror', ' freedom']
#
# SEN
# [' peace', ' security', ' war', ' human rights', ' freedom', ' trade', ' islam']
#
# SGP
# [' war', ' peace', ' security', ' trade', ' economy', ' growth', ' terror']
#
# SLB
# [' peace', ' security', ' nuclear', ' sustainable', ' war', ' human rights', ' weapons']
#
# SLE
# [' peace', ' security', ' war', ' human rights', ' trade', ' poverty', ' refugee']
#
# SLV
# [' peace', ' security', ' democracy', ' human rights', ' war', ' freedom', ' terror']
#
# SMR
# [' peace', ' security', ' violence', ' human rights', ' freedom', ' terror', ' war']
#
# SOM
# [' peace', ' security', ' war', ' refugee', ' nuclear', ' terror', ' human rights']
#
# SSD
# [' peace', ' security', ' oil', ' human rights', ' war', ' education', ' infrastructure']
#
# STP
# [' peace', ' security', ' war', ' poverty', ' freedom', ' terror', ' trade']
#
# SUR
# [' peace', ' security', ' war', ' nuclear', ' human rights', ' trade', ' poverty']
#
# SVK
# [' peace', ' security', ' human rights', ' terror', ' nuclear', ' weapons', ' sustainable']
#
# SVN
# [' security', ' peace', ' human rights', ' war', ' terror', ' weapons', ' nuclear']
#
# SWE
# [' peace', ' security', ' nuclear', ' weapons', ' human rights', ' war', ' nuclear weapons']
#
# SWZ
# [' peace', ' security', ' war', ' weapons', ' trade', ' nuclear', ' poverty']
#
# SYC
# [' peace', ' security', ' economy', ' war', ' sustainable', ' trade', ' terror']
#
# SYR
# [' peace', ' security', ' war', ' terror', ' nuclear', ' weapons', ' sovereignty']
#
# TCD
# [' peace', ' security', ' war', ' terror', ' poverty', ' freedom', ' sovereignty']
#
# TGO
# [' peace', ' security', ' war', ' freedom', ' trade', ' human rights', ' poverty']
#
# THA
# [' peace', ' security', ' war', ' human rights', ' trade', ' refugee', ' food']
#
# TJK
# [' peace', ' water', ' terror', ' sustainable', ' security', ' war', ' energy']
#
# TKM
# [' peace', ' security', ' energy', ' sustainable', ' terror', ' economy', ' infrastructure']
#
# TLS
# [' peace', ' security', ' war', ' violence', ' poverty', ' human rights', ' democracy']
#
# TON
# [' security', ' peace', ' sustainable', ' energy', ' terror', ' health', ' trade']
#
# TTO
# [' peace', ' security', ' trade', ' sustainable', ' war', ' poverty', ' growth']
#
# TUN
# [' peace', ' security', ' war', ' freedom', ' terror', ' weapons', ' human rights']
#
# TUR
# [' peace', ' security', ' terror', ' war', ' human rights', ' nuclear', ' weapons']
# TUV
# [' security', ' peace', ' sustainable', ' war', ' energy', ' terror', ' health']
#
# TZA
# [' peace', ' security', ' war', ' refugee', ' nuclear', ' trade', ' poverty']
#
# UGA
# [' peace', ' security', ' war', ' trade', ' human rights', ' freedom', ' nuclear']
#
# UKR
# [' peace', ' nuclear', ' security', ' weapons', ' war', ' nuclear weapons', ' human rights']
#
# URY
# [' peace', ' security', ' trade', ' human rights', ' terror', ' war', ' democracy']
#
# USA
# [' peace', ' nuclear', ' war', ' security', ' weapons', ' terror', ' freedom']
#
# UZB
# [' security', ' terror', ' peace', ' water', ' nuclear', ' islam', ' war']
#
# VAT
# [' peace', ' war', ' human rights', ' freedom', ' nuclear', ' security', ' terror']
#
# VCT
# [' peace', ' war', ' security', ' trade', ' terror', ' poverty', ' democracy']
#
# VEN
# [' peace', ' war', ' democracy', ' security', ' freedom', ' terror', ' violence']
#
# VNM
# [' peace', ' war', ' security', ' sovereignty', ' nuclear', ' poverty', ' weapons']
#
# VUT
# [' peace', ' security', ' nuclear', ' war', ' weapons', ' democracy', ' terror']
#
# WSM
# [' peace', ' nuclear', ' security', ' weapons', ' war', ' terror', ' sustainable']
#
# YDYE
# [' peace', ' security', ' war', ' sovereignty', ' nuclear', ' freedom', ' weapons']
#
# YEM
# [' peace', ' security', ' war', ' terror', ' freedom', ' weapons', ' nuclear']
#
# YUG
# [' peace', ' security', ' war', ' freedom', ' nuclear', ' terror', ' human rights']
#
# ZAF
# [' peace', ' security', ' poverty', ' war', ' terror', ' weapons', ' human rights']
#
# ZMB
# [' peace', ' security', ' war', ' trade', ' nuclear', ' poverty', ' weapons']
#
# ZWE
# [' peace', ' security', ' war', ' nuclear', ' trade', ' poverty', ' weapons']

# %% [markdown]
# Well folks, that's a wrap!
#
# I hope my introductory kernel was of some help and interest.
